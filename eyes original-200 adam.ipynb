# %%
import os
import torch
from ultralytics import YOLO
from roboflow import Roboflow

# Check available GPUs
num_gpus = torch.cuda.device_count()
device_ids = list(range(num_gpus))  # Example: [0,1,2,3] if 4 GPUs are available

# Define dataset path
dataset_path = "/home/mansi/Sumit Kumar, Satyendra/Effect of augmentation/Eyes-original"
data_yaml = os.path.join(dataset_path, "data.yaml")

# Check if dataset exists
if not os.path.exists(data_yaml):
    print("Dataset not found! Downloading...")
    rf = Roboflow(api_key="2kT053S4dqKLHoB6yTpk")
    project = rf.workspace("bitter-gourd-augemented-dataset").project("eyes-jp15h")
    version = project.version(1)
    dataset = version.download("yolov11")
    
    # Rename and move dataset to the desired path
    os.rename(dataset.location, dataset_path)
else:
    print("Dataset already exists. Using the existing dataset.")

# Load YOLO model
model = YOLO("yolo11n")  # Adjust model if needed

# Train with optimized settings
model.train(
    data=data_yaml, 
    device=device_ids,  # Use all available GPUs
    epochs=200, 
    batch=32,  # Adjust batch size for better GPU utilization
    workers=8,  # Use multiple data loading workers
    optimizer="Adam"  # Use SGD optimizer
)
# Out:
# Dataset already exists. Using the existing dataset.
# Ultralytics 8.3.99 🚀 Python-3.8.13 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:2 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:3 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
# ...

# %%
# Validation
print("Running validation...")
metrics = model.val()
print("Validation Results:", metrics)
# Out:
# Running validation...
# Ultralytics 8.3.99 🚀 Python-3.8.13 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:2 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:3 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
# val: Scanning /home/mansi/Sumit Kumar, Satyendra/Effect of augmentation/Eyes-0.1-2/valid/labels.cache... 9540 images, 0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 299/299 [00:4
#                    all       9540       9540      0.727      0.781      0.805      0.805
#                      0       4387       4387      0.854      0.987      0.953      0.953
# ...

# %%
# Testing
print("Running testing...")
test_results = model.val(split="test")
print("Test Results:", test_results)
# Out:
# Running testing...
# Ultralytics 8.3.99 🚀 Python-3.8.13 torch-2.4.1+cu121 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:1 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:2 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
#                                                       CUDA:3 (NVIDIA GeForce RTX 2080 Ti, 11012MiB)
# val: Scanning /home/mansi/Sumit Kumar, Satyendra/Effect of augmentation/Eyes-0.1-2/test/labels... 3930 images, 0 backgro
# val: New cache created: /home/mansi/Sumit Kumar, Satyendra/Effect of augmentation/Eyes-0.1-2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 123/123 [00:1
#                    all       3930       3930      0.736      0.786      0.815      0.815
#                      0       1807       1807      0.843      0.989      0.944      0.943
# ...

# %%
# Inference
print("Running inference on a sample image...")
image_path = "path_to_your_sample_image.jpg"  # Change this to an actual image path
results = model(image_path)

# Display results
for r in results:
    r.show()  # Show image with detections
    r.save(filename="output.jpg")  # Save output image

print("Inference complete. Results saved as output.jpg")
